# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# In this Notebook, Data Science Tools and Ecosystem is summarized

# %% [markdown]
# __Objectives__:
# 1. List popular languages for Data Science<br>
# 2. List common Libraries used by Data Scientists<br>
# 3. Examples for evaluating arithmetic expressions<br>

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# Python , R , SQL etc

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# Numpy, Pandas, Scikit-learn, Matplotlib etc

# %% [markdown]
# | Data Science Tools   |
# |----------------------|
# | Jupyter Notebooks    |
# | RStudio              |
# | VS Code (with Python)|

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hrs = minutes/60

# %% [markdown]
# <h2>Author</h2><br>
# Syed Muazuddin
